# %% [markdown]
# # Data Into Python

# %%
#Load your packages
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import pandas as pa

# %matplotlib inline

# %%
#https://docs.scipy.org/doc/scipy/reference/stats.html

# %% [markdown]
# # But What is it?

# %% [markdown]
# "The file called train.csv must be inside the same file folder as this file!

# %%
data = pa.read_csv('.csv')

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
#Cool huh?  Panda is a data frame construct so some really great stuff works with it!

# %%
data["Age"] #Returns just the Age column
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
# 5       NaN
# 6      54.0
# 7       2.0
# 8      27.0
# 9      14.0
# 10      4.0
# 11     58.0
# 12     20.0
# 13     39.0
# 14     14.0
# 15     55.0
# 16      2.0
# 17      NaN
# 18     31.0
# 19      NaN
# 20     35.0
# 21     34.0
# 22     15.0
# 23     28.0
# 24      8.0
# 25     38.0
# 26      NaN
# 27     19.0
# 28      NaN
# 29      NaN
#        ...
# 861    21.0
# 862    48.0
# 863     NaN
# 864    24.0
# 865    42.0
# 866    27.0
# 867    31.0
# 868     NaN
# 869     4.0
# 870    26.0
# 871    47.0
# 872    33.0
# 873    47.0
# 874    28.0
# 875    15.0
# 876    20.0
# 877    19.0
# 878     NaN
# 879    56.0
# 880    25.0
# 881    33.0
# 882    22.0
# 883    28.0
# 884    25.0
# 885    39.0
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
np.mean(data["Age"])
# Out:
# 29.69911764705882

# %%
np.std(data["Age"],ddof = 1)
# Out:
# 14.526497332334044

# %%
 stats.describe(data["Age"])#This does not work with the missing data...
# Out:
# DescribeResult(nobs=891, minmax=(nan, nan), mean=nan, variance=nan, skewness=nan, kurtosis=nan)

# %%
age = data["Age"].dropna()#I removed all the NaN's

# %%
stats.describe(age)
# Out:
# DescribeResult(nobs=714, minmax=(0.41999999999999998, 80.0), mean=29.69911764705882, variance=211.01912474630805, skewness=0.3882898514698657, kurtosis=0.16863657224286044)

# %%
# Out:
# array([11, 12])

# %%
# Out:
# (9,)

# %%
# Out:
# 1.959963984540054

# %%
# Out:
# 0.22792675938280152

# %%
# Out:
# So p is in betweeen 0.5902550587990167 and 1.0461085775646197

# %%
# Out:
# 0.3989422804014327

# %%
# Out:
# 0.5

# %%
# Out:
# 0.38910838396603109

# %%
# Out:
# 0.5

# %%
x= np.arange(-4,4,0.001)
plt.plot(x, stats.t.pdf(x,4))
plt.plot(x, stats.norm.pdf(x))

plt.show()
